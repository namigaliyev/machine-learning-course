# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
np.random.seed(12) 
np.random.randn(5)

x = np.arange(1, 10)
x = np.linspace(-np.pi, np.pi, num = 50)
xx = np.transpose(np.tile(x, (50,1)))

y = x
yy = np.tile(y, (50,1))
f = np.zeros((len(x),len(y)))
for i in range(len(x)):
    for j in range(len(y)):
        f[i,j] = np.cos(y[j])/(1+x[i]**2)
plt.contour(f)
plt.contour(f, levels = 45)

fa = (f-np.transpose(f))/2
plt.contour(fa, levels = 45)
plt.imshow(fa)

# %%
data = pd.read_csv('dtist.csv', sep = ',')
data = data.rename(columns={"İlçe": "ilce"})

fig = plt.figure()
ax = fig.gca()
ax.plot(data['2015'], data['2016'], 'bo')
lims = [
    np.min([ax.get_xlim(), ax.get_xlim()]),
    np.max([ax.get_xlim(), ax.get_xlim()])
]
lims
# Out:
# [-13362440.5, 304236280.5]

# %%
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
for i, txt in enumerate(data['ilce']):
    ax.annotate(txt, (data['2015'][i], data['2016'][i]))

plt.hist(data['2019'])
plt.hist(data['2019'], bins = 4)
# Out:
# (array([10., 21.,  7.,  1.]),
#  array([5.84588300e+06, 1.00046512e+08, 1.94247142e+08, 2.88447771e+08,
#         3.82648400e+08]),
#  <a list of 4 Patch objects>)

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 6 columns):
# ilce    39 non-null object
# 2015    39 non-null int64
# 2016    39 non-null int64
# 2017    39 non-null int64
# 2018    39 non-null int64
# 2019    39 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 2.0+ KB
#                2015          2016          2017          2018          2019
# count  3.900000e+01  3.900000e+01  3.900000e+01  3.900000e+01  3.900000e+01
# mean   1.409778e+08  1.478729e+08  1.660643e+08  1.646876e+08  1.474202e+08
# std    7.204390e+07  7.224456e+07  7.993882e+07  7.955643e+07  7.188457e+07
# min    1.073865e+06  5.617081e+06  6.657895e+06  6.321074e+06  5.845883e+06
# 25%    9.464689e+07  9.575070e+07  1.108387e+08  1.120584e+08  1.012423e+08
# 50%    1.400129e+08  1.474701e+08  1.621150e+08  1.656628e+08  1.442630e+08
# 75%    1.805840e+08  1.892539e+08  2.056298e+08  1.985190e+08  1.762696e+08
# ...
